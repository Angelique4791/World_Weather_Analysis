# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieving data for list of cities

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})
                          
                          
                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | itagiba
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | lompoc
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | itoman
# Processing Record 16 of Set 1 | huangmei
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | paamiut
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | saint anthony
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | loksa
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | ola
# Processing Record 27 of Set 1 | starosubkhangulovo
# Processing Record 28 of Set 1 | tonk
# Processing Record 29 of Set 1 | trelew
# Processing Record 30 of Set 1 | baruun-urt
# Processing Record 31 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | maniitsoq
# Processing Record 36 of Set 1 | catuday
# Processing Record 37 of Set 1 | peniche
# Processing Record 38 of Set 1 | upington
# Processing Record 39 of Set 1 | lakatoro
# Processing Record 40 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 1 | nyurba
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | gayeri
# Processing Record 45 of Set 1 | santiago del estero
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | cayenne
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | stege
# Processing Record 1 of Set 2 | nam phong
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | kerteh
# City not found. Skipping...
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | tawzar
# City not found. Skipping...
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | broome
# Processing Record 8 of Set 2 | seoul
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | hay river
# Processing Record 13 of Set 2 | caravelas
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | newport
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | ardakan
# Processing Record 19 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 2 | mount isa
# Processing Record 21 of Set 2 | la tuque
# Processing Record 22 of Set 2 | college
# Processing Record 23 of Set 2 | konevo
# Processing Record 24 of Set 2 | sorong
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | boende
# Processing Record 29 of Set 2 | galesong
# Processing Record 30 of Set 2 | marawi
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | leh
# Processing Record 35 of Set 2 | mataram
# Processing Record 36 of Set 2 | dickson
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | davlekanovo
# Processing Record 40 of Set 2 | port keats
# Processing Record 41 of Set 2 | pau brasil
# Processing Record 42 of Set 2 | nioro
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | yerbogachen
# Processing Record 45 of Set 2 | chumikan
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | grindavik
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | zolochiv
# Processing Record 2 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | palana
# Processing Record 6 of Set 3 | atar
# Processing Record 7 of Set 3 | lucapa
# Processing Record 8 of Set 3 | huancavelica
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | le port
# Processing Record 11 of Set 3 | chapais
# Processing Record 12 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | mahanje
# Processing Record 15 of Set 3 | najran
# Processing Record 16 of Set 3 | tabas
# Processing Record 17 of Set 3 | yar-sale
# Processing Record 18 of Set 3 | kropotkin
# Processing Record 19 of Set 3 | acarau
# Processing Record 20 of Set 3 | san cristobal
# Processing Record 21 of Set 3 | santa marta
# Processing Record 22 of Set 3 | padilla
# Processing Record 23 of Set 3 | te anau
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | mormugao
# Processing Record 27 of Set 3 | vardo
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | kuusamo
# Processing Record 30 of Set 3 | lieto
# Processing Record 31 of Set 3 | meulaboh
# Processing Record 32 of Set 3 | hami
# Processing Record 33 of Set 3 | novoilinskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | mwinilunga
# Processing Record 36 of Set 3 | kerikeri
# Processing Record 37 of Set 3 | sinegorye
# Processing Record 38 of Set 3 | tautira
# Processing Record 39 of Set 3 | collie
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | aliwal north
# Processing Record 42 of Set 3 | esperance
# Processing Record 43 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 3 | itarema
# Processing Record 45 of Set 3 | taretan
# Processing Record 46 of Set 3 | litovko
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | zhigansk
# Processing Record 49 of Set 3 | taltal
# Processing Record 50 of Set 3 | nassau
# Processing Record 1 of Set 4 | shingu
# Processing Record 2 of Set 4 | nemuro
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | gat
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | kanye
# Processing Record 8 of Set 4 | kihei
# Processing Record 9 of Set 4 | altamont
# Processing Record 10 of Set 4 | kapoeta
# Processing Record 11 of Set 4 | skierniewice
# Processing Record 12 of Set 4 | gavrilovka vtoraya
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 4 | billings
# Processing Record 16 of Set 4 | rio grande
# Processing Record 17 of Set 4 | praia da vitoria
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | pokhara
# Processing Record 20 of Set 4 | bafq
# Processing Record 21 of Set 4 | novyy urengoy
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | yulara
# Processing Record 24 of Set 4 | lichinga
# Processing Record 25 of Set 4 | kashan
# Processing Record 26 of Set 4 | palmer
# Processing Record 27 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 4 | kirakira
# Processing Record 29 of Set 4 | merseburg
# Processing Record 30 of Set 4 | pedernales
# Processing Record 31 of Set 4 | gotsu
# Processing Record 32 of Set 4 | college station
# Processing Record 33 of Set 4 | okhotsk
# Processing Record 34 of Set 4 | mnogovershinnyy
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | half moon bay
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | fatehabad
# Processing Record 39 of Set 4 | adrar
# Processing Record 40 of Set 4 | tha chang
# Processing Record 41 of Set 4 | port blair
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | aswan
# Processing Record 44 of Set 4 | senekal
# Processing Record 45 of Set 4 | pevek
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | tapes
# Processing Record 48 of Set 4 | kamaishi
# Processing Record 49 of Set 4 | cidreira
# Processing Record 50 of Set 4 | tuatapere
# Processing Record 1 of Set 5 | karaj
# Processing Record 2 of Set 5 | ferrol
# Processing Record 3 of Set 5 | malartic
# Processing Record 4 of Set 5 | at-bashi
# Processing Record 5 of Set 5 | dalvik
# Processing Record 6 of Set 5 | virginia beach
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 5 | kurmanayevka
# Processing Record 10 of Set 5 | huarmey
# Processing Record 11 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 5 | mandalgovi
# Processing Record 13 of Set 5 | majene
# Processing Record 14 of Set 5 | nikolskoye
# Processing Record 15 of Set 5 | turayf
# Processing Record 16 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 17 of Set 5 | dalkeith
# Processing Record 18 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 5 | riyadh
# Processing Record 20 of Set 5 | sinnamary
# Processing Record 21 of Set 5 | kaeo
# Processing Record 22 of Set 5 | maceio
# Processing Record 23 of Set 5 | llallagua
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | malinyi
# Processing Record 26 of Set 5 | norfolk
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | kutum
# Processing Record 29 of Set 5 | thompson
# Processing Record 30 of Set 5 | teya
# Processing Record 31 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 32 of Set 5 | puerto quijarro
# Processing Record 33 of Set 5 | carnarvon
# Processing Record 34 of Set 5 | launceston
# Processing Record 35 of Set 5 | otane
# Processing Record 36 of Set 5 | susanville
# Processing Record 37 of Set 5 | berlevag
# Processing Record 38 of Set 5 | riohacha
# Processing Record 39 of Set 5 | los llanos de aridane
# Processing Record 40 of Set 5 | morondava
# Processing Record 41 of Set 5 | monticello
# Processing Record 42 of Set 5 | olafsvik
# Processing Record 43 of Set 5 | kumta
# Processing Record 44 of Set 5 | plouzane
# Processing Record 45 of Set 5 | komsomolskiy
# Processing Record 46 of Set 5 | saint-philippe
# Processing Record 47 of Set 5 | kathu
# Processing Record 48 of Set 5 | ullapool
# Processing Record 49 of Set 5 | mount gambier
# Processing Record 50 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 6 | semporna
# Processing Record 2 of Set 6 | aklavik
# Processing Record 3 of Set 6 | saskylakh
# Processing Record 4 of Set 6 | sola
# Processing Record 5 of Set 6 | poronaysk
# Processing Record 6 of Set 6 | yumen
# Processing Record 7 of Set 6 | korgen
# Processing Record 8 of Set 6 | tessalit
# Processing Record 9 of Set 6 | sozimskiy
# Processing Record 10 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 6 | lorengau
# Processing Record 12 of Set 6 | tabory
# Processing Record 13 of Set 6 | sisophon
# Processing Record 14 of Set 6 | gamba
# Processing Record 15 of Set 6 | tougan
# Processing Record 16 of Set 6 | kavaratti
# Processing Record 17 of Set 6 | acapulco
# Processing Record 18 of Set 6 | jati
# Processing Record 19 of Set 6 | noumea
# Processing Record 20 of Set 6 | warri
# Processing Record 21 of Set 6 | monrovia
# Processing Record 22 of Set 6 | deulgaon raja
# Processing Record 23 of Set 6 | nechanice
# Processing Record 24 of Set 6 | purpe
# Processing Record 25 of Set 6 | coari
# Processing Record 26 of Set 6 | kendari
# Processing Record 27 of Set 6 | pasni
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | eganville
# Processing Record 30 of Set 6 | ereymentau
# Processing Record 31 of Set 6 | norman wells
# Processing Record 32 of Set 6 | puerto del rosario
# Processing Record 33 of Set 6 | talnakh
# Processing Record 34 of Set 6 | albert town
# Processing Record 35 of Set 6 | nalut
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | quevedo
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | koltsovo
# Processing Record 40 of Set 6 | anadyr
# Processing Record 41 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 6 | maragogi
# Processing Record 43 of Set 6 | hasaki
# Processing Record 44 of Set 6 | oksfjord
# Processing Record 45 of Set 6 | hazorasp
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | westport
# Processing Record 48 of Set 6 | assiniboia
# Processing Record 49 of Set 6 | novopskov
# Processing Record 50 of Set 6 | avarua
# Processing Record 1 of Set 7 | edremit
# Processing Record 2 of Set 7 | bardiyah
# Processing Record 3 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 4 of Set 7 | muroto
# Processing Record 5 of Set 7 | bagdarin
# Processing Record 6 of Set 7 | labuan
# Processing Record 7 of Set 7 | bairiki
# Processing Record 8 of Set 7 | george
# Processing Record 9 of Set 7 | sayyan
# Processing Record 10 of Set 7 | makakilo city
# Processing Record 11 of Set 7 | east moline
# Processing Record 12 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 7 | chiredzi
# Processing Record 14 of Set 7 | shelburne
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | coahuayana
# Processing Record 17 of Set 7 | portland
# Processing Record 18 of Set 7 | port hedland
# Processing Record 19 of Set 7 | buala
# Processing Record 20 of Set 7 | cacapava do sul
# Processing Record 21 of Set 7 | butaritari
# Processing Record 22 of Set 7 | kahului
# Processing Record 23 of Set 7 | kungurtug
# Processing Record 24 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | gigmoto
# Processing Record 29 of Set 7 | lewistown
# Processing Record 30 of Set 7 | mayaky
# Processing Record 31 of Set 7 | pasighat
# Processing Record 32 of Set 7 | kallaste
# Processing Record 33 of Set 7 | kasongo-lunda
# Processing Record 34 of Set 7 | rawson
# Processing Record 35 of Set 7 | saint george
# Processing Record 36 of Set 7 | nador
# Processing Record 37 of Set 7 | letnyaya stavka
# Processing Record 38 of Set 7 | uyemskiy
# Processing Record 39 of Set 7 | vao
# Processing Record 40 of Set 7 | onega
# Processing Record 41 of Set 7 | makokou
# Processing Record 42 of Set 7 | sorel
# Processing Record 43 of Set 7 | odweyne
# Processing Record 44 of Set 7 | nanortalik
# Processing Record 45 of Set 7 | ayacucho
# Processing Record 46 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 7 | santiago de cuba
# Processing Record 48 of Set 7 | yining
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 50 of Set 7 | rocha
# Processing Record 1 of Set 8 | tynda
# Processing Record 2 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 8 | ximei
# Processing Record 4 of Set 8 | parrita
# Processing Record 5 of Set 8 | mayari
# City not found. Skipping...
# Processing Record 6 of Set 8 | bubaque
# Processing Record 7 of Set 8 | mackay
# Processing Record 8 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 8 | wonthaggi
# Processing Record 10 of Set 8 | lata
# Processing Record 11 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 8 | shimoda
# Processing Record 13 of Set 8 | beloha
# Processing Record 14 of Set 8 | flinders
# Processing Record 15 of Set 8 | khorixas
# Processing Record 16 of Set 8 | roma
# Processing Record 17 of Set 8 | valley city
# Processing Record 18 of Set 8 | krynychky
# Processing Record 19 of Set 8 | saint-pierre
# Processing Record 20 of Set 8 | bathsheba
# Processing Record 21 of Set 8 | kruisfontein
# Processing Record 22 of Set 8 | areia branca
# Processing Record 23 of Set 8 | mae sai
# Processing Record 24 of Set 8 | punta cardon
# Processing Record 25 of Set 8 | miri
# Processing Record 26 of Set 8 | lewisburg
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | clyde river
# Processing Record 29 of Set 8 | hobyo
# Processing Record 30 of Set 8 | luocheng
# Processing Record 31 of Set 8 | the valley
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | mikumi
# Processing Record 34 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 8 | cherskiy
# Processing Record 36 of Set 8 | harnai
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | groningen
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 8 | srivardhan
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | mahebourg
# Processing Record 45 of Set 8 | beaverlodge
# Processing Record 46 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | uturoa
# Processing Record 48 of Set 8 | sitka
# Processing Record 49 of Set 8 | belmonte
# Processing Record 50 of Set 8 | yablonovo
# Processing Record 1 of Set 9 | tilichiki
# Processing Record 2 of Set 9 | nara
# Processing Record 3 of Set 9 | nanakuli
# Processing Record 4 of Set 9 | oriximina
# Processing Record 5 of Set 9 | hirara
# Processing Record 6 of Set 9 | oussouye
# Processing Record 7 of Set 9 | brufut
# Processing Record 8 of Set 9 | saint-augustin
# Processing Record 9 of Set 9 | bazarnyye mataki
# Processing Record 10 of Set 9 | erenhot
# Processing Record 11 of Set 9 | kosh-agach
# Processing Record 12 of Set 9 | cesme
# Processing Record 13 of Set 9 | ust-tsilma
# Processing Record 14 of Set 9 | svetlogorsk
# Processing Record 15 of Set 9 | port hardy
# Processing Record 16 of Set 9 | polgardi
# Processing Record 17 of Set 9 | bucerias
# Processing Record 18 of Set 9 | zyryanka
# Processing Record 19 of Set 9 | severo-kurilsk
# Processing Record 20 of Set 9 | pervomayskoye
# Processing Record 21 of Set 9 | canakkale
# Processing Record 22 of Set 9 | high level
# Processing Record 23 of Set 9 | thunder bay
# Processing Record 24 of Set 9 | eureka
# Processing Record 25 of Set 9 | nueva guinea
# Processing Record 26 of Set 9 | henties bay
# Processing Record 27 of Set 9 | lorica
# Processing Record 28 of Set 9 | east london
# Processing Record 29 of Set 9 | nusaybin
# Processing Record 30 of Set 9 | sao joao da barra
# Processing Record 31 of Set 9 | miles city
# Processing Record 32 of Set 9 | buchanan
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | torbay
# Processing Record 35 of Set 9 | bojnurd
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | anaconda
# Processing Record 38 of Set 9 | southbridge
# Processing Record 39 of Set 9 | nome
# Processing Record 40 of Set 9 | fairbanks
# Processing Record 41 of Set 9 | zhengjiatun
# Processing Record 42 of Set 9 | teahupoo
# Processing Record 43 of Set 9 | portales
# Processing Record 44 of Set 9 | am timan
# Processing Record 45 of Set 9 | omboue
# Processing Record 46 of Set 9 | ekibastuz
# Processing Record 47 of Set 9 | mufumbwe
# Processing Record 48 of Set 9 | sao filipe
# Processing Record 49 of Set 9 | kon tum
# Processing Record 50 of Set 9 | andenes
# Processing Record 1 of Set 10 | marrakesh
# Processing Record 2 of Set 10 | dalinghe
# City not found. Skipping...
# Processing Record 3 of Set 10 | taos
# Processing Record 4 of Set 10 | pochutla
# Processing Record 5 of Set 10 | terracina
# Processing Record 6 of Set 10 | asfi
# Processing Record 7 of Set 10 | tamandare
# Processing Record 8 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 10 | ponta delgada
# Processing Record 10 of Set 10 | leon
# Processing Record 11 of Set 10 | padang
# Processing Record 12 of Set 10 | mocuba
# Processing Record 13 of Set 10 | kemijarvi
# Processing Record 14 of Set 10 | angoche
# Processing Record 15 of Set 10 | hit
# Processing Record 16 of Set 10 | cap malheureux
# Processing Record 17 of Set 10 | madera
# Processing Record 18 of Set 10 | nenjiang
# Processing Record 19 of Set 10 | canutama
# Processing Record 20 of Set 10 | safaga
# Processing Record 21 of Set 10 | imbituba
# Processing Record 22 of Set 10 | bushehr
# Processing Record 23 of Set 10 | leningradskiy
# Processing Record 24 of Set 10 | oga
# Processing Record 25 of Set 10 | flagstaff
# Processing Record 26 of Set 10 | montepuez
# Processing Record 27 of Set 10 | narva-joesuu
# Processing Record 28 of Set 10 | guaruja
# Processing Record 29 of Set 10 | nabire
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | lodwar
# Processing Record 32 of Set 10 | sulangan
# Processing Record 33 of Set 10 | bilma
# Processing Record 34 of Set 10 | quatre cocos
# Processing Record 35 of Set 10 | frederiksberg
# Processing Record 36 of Set 10 | carutapera
# Processing Record 37 of Set 10 | osvaldo cruz
# Processing Record 38 of Set 10 | brumado
# Processing Record 39 of Set 10 | stornoway
# Processing Record 40 of Set 10 | kawalu
# Processing Record 41 of Set 10 | sawankhalok
# Processing Record 42 of Set 10 | necochea
# Processing Record 43 of Set 10 | varhaug
# Processing Record 44 of Set 10 | vila franca do campo
# Processing Record 45 of Set 10 | zanatepec
# City not found. Skipping...
# Processing Record 46 of Set 10 | huanan
# Processing Record 47 of Set 10 | perustica
# City not found. Skipping...
# Processing Record 48 of Set 10 | zaraza
# Processing Record 49 of Set 10 | tolaga bay
# Processing Record 50 of Set 10 | dwarka
# Processing Record 1 of Set 11 | yazman
# Processing Record 2 of Set 11 | port macquarie
# Processing Record 3 of Set 11 | arona
# Processing Record 4 of Set 11 | champerico
# Processing Record 5 of Set 11 | ballina
# Processing Record 6 of Set 11 | hisor
# Processing Record 7 of Set 11 | fethiye
# Processing Record 8 of Set 11 | kyzyl
# Processing Record 9 of Set 11 | weligama
# Processing Record 10 of Set 11 | avera
# Processing Record 11 of Set 11 | pueblo
# Processing Record 12 of Set 11 | guerrero negro
# Processing Record 13 of Set 11 | la ronge
# Processing Record 14 of Set 11 | brainerd
# Processing Record 15 of Set 11 | sembe
# Processing Record 16 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 11 | laredo
# Processing Record 18 of Set 11 | ternate
# Processing Record 19 of Set 11 | samarai
# Processing Record 20 of Set 11 | tromso
# Processing Record 21 of Set 11 | general pico
# Processing Record 22 of Set 11 | pachino
# Processing Record 23 of Set 11 | tairua
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | kichera
# Processing Record 26 of Set 11 | rajauri
# Processing Record 27 of Set 11 | chapaevsk
# Processing Record 28 of Set 11 | ferry pass
# Processing Record 29 of Set 11 | simao
# Processing Record 30 of Set 11 | vestmanna
# Processing Record 31 of Set 11 | isangel
# Processing Record 32 of Set 11 | novikovo
# Processing Record 33 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 11 | honiara
# Processing Record 35 of Set 11 | revelstoke
# Processing Record 36 of Set 11 | kjopsvik
# Processing Record 37 of Set 11 | ankola
# Processing Record 38 of Set 11 | panguna
# Processing Record 39 of Set 11 | nakamura
# Processing Record 40 of Set 11 | marshfield
# Processing Record 41 of Set 11 | pisco
# Processing Record 42 of Set 11 | inhambane
# Processing Record 43 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 11 | griffith
# Processing Record 45 of Set 11 | gushikawa
# Processing Record 46 of Set 11 | nisia floresta
# Processing Record 47 of Set 11 | athabasca
# Processing Record 48 of Set 11 | haines junction
# Processing Record 49 of Set 11 | mehamn
# Processing Record 50 of Set 11 | san vicente
# Processing Record 1 of Set 12 | manturovo
# Processing Record 2 of Set 12 | murmashi
# Processing Record 3 of Set 12 | storrs
# Processing Record 4 of Set 12 | san carlos de bariloche
# Processing Record 5 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 6 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 12 | chapel hill
# Processing Record 8 of Set 12 | mujiayingzi
# Processing Record 9 of Set 12 | inirida
# Processing Record 10 of Set 12 | polunochnoye
# Processing Record 11 of Set 12 | wad madani
# Processing Record 12 of Set 12 | nouadhibou
# Processing Record 13 of Set 12 | evensk
# Processing Record 14 of Set 12 | luwuk
# Processing Record 15 of Set 12 | hirado
# Processing Record 16 of Set 12 | barcelona
# Processing Record 17 of Set 12 | tual
# Processing Record 18 of Set 12 | mechetinskaya
# Processing Record 19 of Set 12 | fukue
# Processing Record 20 of Set 12 | alenquer
# Processing Record 21 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 22 of Set 12 | erdenet
# Processing Record 23 of Set 12 | iqaluit
# Processing Record 24 of Set 12 | strezhevoy
# Processing Record 25 of Set 12 | laurel
# Processing Record 26 of Set 12 | pavlodar
# Processing Record 27 of Set 12 | margate
# Processing Record 28 of Set 12 | jiaojiang
# Processing Record 29 of Set 12 | aginskoye
# Processing Record 30 of Set 12 | lavrentiya
# Processing Record 31 of Set 12 | sao pedro do sul
# Processing Record 32 of Set 12 | dicabisagan
# Processing Record 33 of Set 12 | bonthe
# Processing Record 34 of Set 12 | sawakin
# Processing Record 35 of Set 12 | taoudenni
# Processing Record 36 of Set 12 | masuda
# Processing Record 37 of Set 12 | shuyskoye
# Processing Record 38 of Set 12 | mecca
# Processing Record 39 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 12 | gerash
# Processing Record 41 of Set 12 | kerema
# Processing Record 42 of Set 12 | nuuk
# Processing Record 43 of Set 12 | venado tuerto
# Processing Record 44 of Set 12 | ginda
# Processing Record 45 of Set 12 | chicama
# Processing Record 46 of Set 12 | puerto colombia
# Processing Record 47 of Set 12 | thinadhoo
# Processing Record 48 of Set 12 | ucluelet
# Processing Record 49 of Set 12 | borgarnes
# Processing Record 50 of Set 12 | basco
# Processing Record 1 of Set 13 | lakselv
# Processing Record 2 of Set 13 | port lincoln
# Processing Record 3 of Set 13 | harnoli
# Processing Record 4 of Set 13 | kupang
# Processing Record 5 of Set 13 | mogadishu
# Processing Record 6 of Set 13 | qasigiannguit
# Processing Record 7 of Set 13 | aden
# Processing Record 8 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 9 of Set 13 | manoel urbano
# Processing Record 10 of Set 13 | gberia fotombu
# Processing Record 11 of Set 13 | alassio
# Processing Record 12 of Set 13 | manta
# Processing Record 13 of Set 13 | nohar
# Processing Record 14 of Set 13 | namibe
# Processing Record 15 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 13 | shakhtinsk
# Processing Record 17 of Set 13 | ulan-ude
# Processing Record 18 of Set 13 | yamaga
# Processing Record 19 of Set 13 | tacuarembo
# Processing Record 20 of Set 13 | parabel
# Processing Record 21 of Set 13 | rusape
# Processing Record 22 of Set 13 | tezu
# Processing Record 23 of Set 13 | faridkot
# Processing Record 24 of Set 13 | lucea
# Processing Record 25 of Set 13 | waddan
# Processing Record 26 of Set 13 | charleston
# Processing Record 27 of Set 13 | kita
# Processing Record 28 of Set 13 | tinskoy
# Processing Record 29 of Set 13 | dichiseni
# Processing Record 30 of Set 13 | tomatlan
# Processing Record 31 of Set 13 | sao joao dos patos
# Processing Record 32 of Set 13 | huatulco
# Processing Record 33 of Set 13 | arlit
# Processing Record 34 of Set 13 | bedford
# Processing Record 35 of Set 13 | lakes entrance
# Processing Record 36 of Set 13 | biltine
# Processing Record 37 of Set 13 | maitum
# Processing Record 38 of Set 13 | esso
# Processing Record 39 of Set 13 | matay
# Processing Record 40 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 41 of Set 13 | tooele
# Processing Record 42 of Set 13 | cockburn town
# Processing Record 43 of Set 13 | pala
# Processing Record 44 of Set 13 | cairns
# Processing Record 45 of Set 13 | khuzhir
# Processing Record 46 of Set 13 | tigil
# Processing Record 47 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 13 | ambulu
# Processing Record 49 of Set 13 | savalou
# Processing Record 50 of Set 13 | causapscal
# Processing Record 1 of Set 14 | estelle
# Processing Record 2 of Set 14 | ambilobe
# Processing Record 3 of Set 14 | korostyshiv
# Processing Record 4 of Set 14 | mahibadhoo
# Processing Record 5 of Set 14 | bakchar
# Processing Record 6 of Set 14 | torfyanoy
# Processing Record 7 of Set 14 | jizan
# Processing Record 8 of Set 14 | havre-saint-pierre
# Processing Record 9 of Set 14 | shaunavon
# Processing Record 10 of Set 14 | bull savanna
# Processing Record 11 of Set 14 | smirnykh
# Processing Record 12 of Set 14 | richards bay
# Processing Record 13 of Set 14 | bajil
# Processing Record 14 of Set 14 | pran buri
# Processing Record 15 of Set 14 | smithers
# Processing Record 16 of Set 14 | treuchtlingen
# Processing Record 17 of Set 14 | flin flon
# Processing Record 18 of Set 14 | whitianga
# Processing Record 19 of Set 14 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 20 of Set 14 | fort nelson
# Processing Record 21 of Set 14 | tokmak
# Processing Record 22 of Set 14 | baykit
# Processing Record 23 of Set 14 | bilibino
# Processing Record 24 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 14 | wasilla
# Processing Record 26 of Set 14 | krasnofarfornyy
# Processing Record 27 of Set 14 | kidal
# Processing Record 28 of Set 14 | gornozavodsk
# Processing Record 29 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 14 | bambanglipuro
# Processing Record 31 of Set 14 | tuyen quang
# Processing Record 32 of Set 14 | etchoropo
# Processing Record 33 of Set 14 | celestun
# Processing Record 34 of Set 14 | chinna salem
# Processing Record 35 of Set 14 | mbuguni
# Processing Record 36 of Set 14 | boyolangu
# Processing Record 37 of Set 14 | faya
# Processing Record 38 of Set 14 | malakal
# Processing Record 39 of Set 14 | taremskoye
# Processing Record 40 of Set 14 | prado
# Processing Record 41 of Set 14 | miandrivazo
# Processing Record 42 of Set 14 | kysyl-syr
# Processing Record 43 of Set 14 | balykshi
# Processing Record 44 of Set 14 | keetmanshoop
# Processing Record 45 of Set 14 | kasempa
# Processing Record 46 of Set 14 | plettenberg bay
# Processing Record 47 of Set 14 | albanel
# Processing Record 48 of Set 14 | gravdal
# Processing Record 49 of Set 14 | merritt island
# Processing Record 50 of Set 14 | bowen
# Processing Record 1 of Set 15 | mareeba
# Processing Record 2 of Set 15 | christchurch
# Processing Record 3 of Set 15 | heyang
# Processing Record 4 of Set 15 | port huron
# Processing Record 5 of Set 15 | pula
# Processing Record 6 of Set 15 | wanning
# Processing Record 7 of Set 15 | emerald
# Processing Record 8 of Set 15 | malinovskiy
# Processing Record 9 of Set 15 | lodja
# Processing Record 10 of Set 15 | kofarnihon
# City not found. Skipping...
# Processing Record 11 of Set 15 | point fortin
# Processing Record 12 of Set 15 | eugene
# Processing Record 13 of Set 15 | laguna
# Processing Record 14 of Set 15 | kota bahru
# Processing Record 15 of Set 15 | jalu
# Processing Record 16 of Set 15 | luau
# Processing Record 17 of Set 15 | xai-xai
# Processing Record 18 of Set 15 | kalmunai
# Processing Record 19 of Set 15 | san jose
# Processing Record 20 of Set 15 | sisimiut
# Processing Record 21 of Set 15 | brae
# Processing Record 22 of Set 15 | dogondoutchi
# Processing Record 23 of Set 15 | talara
# Processing Record 24 of Set 15 | port augusta
# Processing Record 25 of Set 15 | lousa
# Processing Record 26 of Set 15 | rio cuarto
# Processing Record 27 of Set 15 | liverpool
# Processing Record 28 of Set 15 | bonavista
# Processing Record 29 of Set 15 | shenjiamen
# Processing Record 30 of Set 15 | zonnebeke
# Processing Record 31 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 15 | lingao
# Processing Record 33 of Set 15 | togur
# Processing Record 34 of Set 15 | tetouan
# Processing Record 35 of Set 15 | havoysund
# Processing Record 36 of Set 15 | sibi
# Processing Record 37 of Set 15 | mabaruma
# Processing Record 38 of Set 15 | broken hill
# Processing Record 39 of Set 15 | hastings
# Processing Record 40 of Set 15 | eskil
# Processing Record 41 of Set 15 | calvinia
# Processing Record 42 of Set 15 | along
# Processing Record 43 of Set 15 | whitehorse
# Processing Record 44 of Set 15 | berbera
# Processing Record 45 of Set 15 | thiruvarur
# Processing Record 46 of Set 15 | kulykiv
# Processing Record 47 of Set 15 | husavik
# Processing Record 48 of Set 15 | zaysan
# Processing Record 49 of Set 15 | tabou
# Processing Record 50 of Set 15 | dasoguz
# Processing Record 1 of Set 16 | deputatskiy
# Processing Record 2 of Set 16 | yakima
# Processing Record 3 of Set 16 | narasaraopet
# Processing Record 4 of Set 16 | hualmay
# Processing Record 5 of Set 16 | buenos aires
# Processing Record 6 of Set 16 | kochubey
# Processing Record 7 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 16 | turbo
# Processing Record 9 of Set 16 | tignere
# Processing Record 10 of Set 16 | udachnyy
# Processing Record 11 of Set 16 | nantucket
# Processing Record 12 of Set 16 | muros
# Processing Record 13 of Set 16 | termiz
# Processing Record 14 of Set 16 | arifwala
# Processing Record 15 of Set 16 | sobolevo
# Processing Record 16 of Set 16 | wlodawa
# Processing Record 17 of Set 16 | pacific grove
# Processing Record 18 of Set 16 | kotka
# Processing Record 19 of Set 16 | alpena
# Processing Record 20 of Set 16 | tommot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Georgetown      MY   5.4112  100.3354     85.95        86          20
# 1         Vaini      TO -21.2000 -175.2000     80.76        89          40
# 2  Beringovskiy      RU  63.0500  179.3167     51.55        69         100
# 3       Mataura      NZ -46.1927  168.8643     47.48        93          99
# 4       Itagiba      BR -14.2836  -39.8428     66.18        99          27
# 5     Hithadhoo      MV  -0.6000   73.0833     80.38        75         100
# 6       Rikitea      PF -23.1203 -134.9692     72.93        75           9
# 7     Busselton      AU -33.6500  115.3333     58.69        59          60
# 8       Ushuaia      AR -54.8000  -68.3000     42.46        70          40
# 9   Yellowknife      CA  62.4560 -114.3525     57.72        72          75
#
#    Wind Speed
# 0        3.44
# 1       10.36
# 2        5.50
# 3        7.72
# 4        1.03
# 5       14.63
# 6       15.93
# 7       10.29
# 8       23.02
# 9        4.61

# %%
city_data_df.to_csv('C:/Users/seang/OneDrive/Desktop/Git_Hub_Portal/World_Weather_Analysis/Weather_Database/city_data.csv', index=False)
