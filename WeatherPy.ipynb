# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# -11.320576784553296 20.426726324039663
# 86.39062568845736 14.02630049041315
# -19.066594145840597 -173.6305563362037
# 59.39138313458517 -57.55502678972779
# 28.221263770333024 -60.78325113301459
# 0.5367182623547677 -136.9415731204876
# -41.54499642153958 150.79269512767996
# -81.42799443173374 -142.6211498662819
# 84.08337240387542 133.65179881393817
# 87.7813807974118 105.07583554511564
# 71.3973757419391 124.04712405217725
# 10.443825267507876 -144.88010605063042
# -39.33029988551637 -169.23984245598558
# -78.56748761500474 -164.82650074005969
# -75.18553066947246 -121.52773667808783
# 81.08301281670703 167.11579707300234
# 37.04807247006234 -41.250115217556555
# 44.52321277287177 131.9036428004461
# -53.39751470512983 28.03484722396763
# -64.03231449007774 -12.250916848974072
# 44.29593588712294 -174.91183263917168
# -71.45477206360914 91.29887427581696
# 43.92472385065932 54.88955732652741
# -28.849469296129804 -178.99644230541736
# -56.82106942198794 76.95085288973735
# ...

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %% [markdown]
# ### Create Practice set of lat/lng.

# %%
# Create a practice set of random latitude and longitude combinations.
p_lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
p_lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
p_lat_lngs = zip(p_lats, p_lngs)

# %%
# Add the latitudes and longitudes to a list.
p_coordinates = list(p_lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for p_coordinate in p_coordinates:
    print(p_coordinate[0], p_coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Use the print() function to display the latitude and longitude combinations.
for p_coordinate in p_coordinates:
    print(citipy.nearest_city(p_coordinate[0], p_coordinate[1]).city_name,
          citipy.nearest_city(p_coordinate[0], p_coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for p_coordinate in p_coordinates:
    city = citipy.nearest_city(p_coordinate[0], p_coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# ['cockburn town', 'gat', 'parvatsar', 'punta arenas', 'saint george']
